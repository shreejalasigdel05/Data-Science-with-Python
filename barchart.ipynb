# %%
#bar chart is used to compare different catagory with there corresponding aggregate value

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
courses=["Python","Java","C","DataScience"]
students_count=[40,30,20,50]
plt.figure(figsize=(6,4))
plt.title("courses vs students_counts")
plt.xlabel("courses")
plt.ylabel("students count")
plt.bar(courses,students_count)
# Out:
# <BarContainer object of 4 artists>

# %%
df=pd.DataFrame({
    "Department":['IT','HR','Sales','Finance'],
    "Employees":[25,15,30,20]
})
plt.figure(figsize=(6,4))
plt.barh(df['Department'],df['Employees']) #barh for horizontal bar chart
plt.title("courses vs students_counts")
plt.ylabel("courses")
plt.xlabel("students count")
plt.savefig("barchart.jpg") #figure saving
plt.show()

# %%
subjects=["DSA","OOP","Database"]
#values(datset)
boys=[80,75,90]
girls=[85,80,88]
x=np.arange(len(subjects)) #[0 1 2 3]
width=0.40
plt.figure(figsize=(6,6))
plt.bar(x-width/2, boys, width, label="Boys")
plt.bar(x+width/2, girls, width, label="Girls")

plt.title("Marks by students")
plt.ylabel("marks")
plt.xlabel("subject")

plt.xticks(x,subjects)
plt.legend()
plt.grid(axis="y")
plt.show()

# %%
# pair plot shows relation among multiple variables.

# %%
df=sns.load_dataset('tips')
df.head(10)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
sns.pairplot(df,hue='sex')

# %%
sns.scatterplot(x='size',y='total', data=df)
sns.lineplot(x='sized',y='total_bill',data=df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 sns.scatterplot(x='size',y='total', data=df)
#       2 sns.lineplot(x='sized',y='total_bill',data=df)
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\seaborn\relational.py:615, in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     606 def scatterplot(
#     607     data=None, *,
#     608     x=None, y=None, hue=None, size=None, style=None,
#    (...)    612     **kwargs
#     613 ):
# --> 615     p = _ScatterPlotter(
#     616         data=data,
#     617         variables=dict(x=x, y=y, hue=hue, size=size, style=style),
#     618         legend=legend
#     619     )
#     621     p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
# ...
