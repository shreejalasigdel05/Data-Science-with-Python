# %%
#data cleaning

# %%
import pandas as pd
import numpy as np

# %%
data={
    "Name":['Samu','Kali','Samu','Gita','None'],
    "Age":[25,30,25,30,28],
    "City":['KTM','BRT','KTM',None,'Dhg'],
    "Salary":[5000,6000,5000,np.nan,60000]
}

# %%
df=pd.DataFrame(data)

# %%
df
cpydf=df

# %%
df.isnull()
# Out:
#     Name    Age   City  Salary
# 0  False  False  False   False
# 1  False  False  False   False
# 2  False  False  False   False
# 3  False  False   True    True
# 4  False  False  False   False

# %%
df.isnull().sum
# Out:
# <bound method DataFrame.sum of     Name    Age   City  Salary
# 0  False  False  False   False
# 1  False  False  False   False
# 2  False  False  False   False
# 3  False  False   True    True
# 4  False  False  False   False>

# %%
df.dropna() #removing null
# Out:
#    Name  Age City   Salary
# 0  Samu   25  KTM   5000.0
# 1  Kali   30  BRT   6000.0
# 2  Samu   25  KTM   5000.0
# 4  None   28  Dhg  60000.0

# %%
cdf=df.dropna(axis=1)

# %%
cdf
# Out:
#    Name  Age
# 0  Samu   25
# 1  Kali   30
# 2  Samu   25
# 3  Gita   30
# 4  None   28

# %%
df_clean=df.dropna(axis=0)
df_clean
# Out:
#    Name  Age City   Salary
# 0  Samu   25  KTM   5000.0
# 1  Kali   30  BRT   6000.0
# 2  Samu   25  KTM   5000.0
# 4  None   28  Dhg  60000.0

# %%
#filling the missing value

# %%
dfzero=df.fillna(0) #replacing missing value with zero

# %%
dfzero
# Out:
#    Name  Age City   Salary
# 0  Samu   25  KTM   5000.0
# 1  Kali   30  BRT   6000.0
# 2  Samu   25  KTM   5000.0
# 3  Gita   30    0      0.0
# 4  None   28  Dhg  60000.0

# %%
df
# Out:
#    Name  Age City   Salary
# 0  Samu   25  KTM   5000.0
# 1  Kali   30  BRT   6000.0
# 2  Samu   25  KTM   5000.0
# 3  Gita   30  NaN      NaN
# 4  None   28  Dhg  60000.0

# %%
age_mean=df['Age'].mean()

# %%
age_mean
# Out:
# np.float64(27.6)

# %%
df['Age']=df['Age'].fillna(age_mean)

# %%
df['Age']
# Out:
# 0    25
# 1    30
# 2    25
# 3    30
# 4    28
# Name: Age, dtype: int64

# %%
df
# Out:
#    Name  Age City   Salary
# 0  Samu   25  KTM   5000.0
# 1  Kali   30  BRT   6000.0
# 2  Samu   25  KTM   5000.0
# 3  Gita   30  NaN      NaN
# 4  None   28  Dhg  60000.0

# %%
df['Age']=df['Age'].fillna(df['Age'].median())

# %%
df['Age']
# Out:
# 0    25
# 1    30
# 2    25
# 3    30
# 4    28
# Name: Age, dtype: int64

# %%
df
# Out:
#    Name  Age City   Salary
# 0  Samu   25  KTM   5000.0
# 1  Kali   30  BRT   6000.0
# 2  Samu   25  KTM   5000.0
# 3  Gita   30  NaN      NaN
# 4  None   28  Dhg  60000.0

# %%
cpydf
# Out:
#    Name  Age City   Salary
# 0  Samu   25  KTM   5000.0
# 1  Kali   30  BRT   6000.0
# 2  Samu   25  KTM   5000.0
# 3  Gita   30  NaN      NaN
# 4  None   28  Dhg  60000.0

# %%
# df=df.ffill() #forward fill (will fill up the nan with the previous value)
# df

# %%
df=df.bfill()
df
# Out:
#    Name  Age City   Salary
# 0  Samu   25  KTM   5000.0
# 1  Kali   30  BRT   6000.0
# 2  Samu   25  KTM   5000.0
# 3  Gita   30  Dhg  60000.0
# 4  None   28  Dhg  60000.0

# %%
dup=df.duplicated() #find the duplicate value
dup
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# dtype: bool

# %%
df=df.drop_duplicates() #revove the duplicated value
df
# Out:
#    Name  Age City   Salary
# 0  Samu   25  KTM   5000.0
# 1  Kali   30  BRT   6000.0
# 3  Gita   30  Dhg  60000.0
# 4  None   28  Dhg  60000.0
