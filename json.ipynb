# %%
#read json
import pandas as pd
url="employee.json"

# %%
df=pd.read_json(url)

# %%
df
# Out:
#    id          name department  salary
# 0   1  Aarav Sharma         IT   60000
# 1   2   Priya Singh         HR   50000
# 2   3   Rohit Kumar    Finance   70000
# 3   4      Sita Rai  Marketing   55000
# 4   5    Anil Thapa         IT   65000
